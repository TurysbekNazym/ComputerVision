# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline
imbyc = img.imread('./bycicle.png')
fig = plt.figure(figsize=(15,10))
plt.subplot(221)
plt.imshow(imbyc,cmap='gray')
plt.show()

# %%
a - 6,3
г - 7
д - 5
в - 4
б - 1

# %%
#d [-1, -2, -1], [0, 0, 0], [1, 2, 1]]
from scipy import ndimage
import numpy as np
k = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])
flt = ndimage.convolve(imbyc, k, mode='nearest', cval=0.0)
fig = plt.figure(figsize=(15,10))
plt.subplot(131)
plt.imshow(flt,cmap='gray')
plt.subplot(132)
plt.imshow(imbyc,cmap='gray')
plt.show()

# %%
#1.V mediann filter
import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline
imlen = img.imread('./bycicle.png')
from scipy import ndimage
import scipy.misc
import numpy as np
from scipy import ndimage as nimg
import numpy as np
im2 =nimg.median_filter(imlen, size=3, footprint=None, output =None, 
                         mode='reflect', cval=0.0, origin = 0)
fig = plt.figure(figsize=(15,10))
plt.subplot(131)
plt.imshow(imlen,cmap='gray')
fig2 = plt.figure(figsize=(15,10))
plt.subplot(132)
plt.imshow(im2,cmap='gray')

# %%
#a 
from scipy import ndimage
import numpy as np
k = np.array([[1/16, 2/16, 1], [2/16, 4/16, 2/16], [1/16, 2/16, 1/16]])
flt = ndimage.convolve(imbyc, k, mode='nearest', cval=0.0)
fig = plt.figure(figsize=(15,10))
plt.subplot(131)
plt.imshow(flt,cmap='gray')
plt.subplot(132)
plt.imshow(imbyc,cmap='gray')
plt.show()

# %%
#b [-1, -2, -1], [0, 0, 0], [1, 2, 1]]
from scipy import ndimage
import numpy as np
k = np.array([[0, 1, 0], [1/5, 1/5, 1/5], [0, 1/5, 0]])
flt = ndimage.convolve(imbyc, k, mode='nearest', cval=0.0)
fig = plt.figure(figsize=(15,10))
plt.subplot(131)
plt.imshow(flt,cmap='gray')
plt.subplot(132)
plt.imshow(imbyc,cmap='gray')
plt.show()

# %%
#g
from scipy import ndimage
import numpy as np
k = np.array([[-1, -2, -1], [-2, 12, -2], [-1,-2, -1]])
flt = ndimage.convolve(imbyc, k, mode='nearest', cval=0.0)
fig = plt.figure(figsize=(15,10))
plt.subplot(131)
plt.imshow(flt,cmap='gray')
plt.subplot(132)
plt.imshow(imbyc,cmap='gray')
plt.show()
